# %% [markdown]
# We may only want the information for a specific set of stops. We could either
# filter the larger datasets returned by the other functions, or use the
# `naptan.get_specific_stops` function and let it do the work.
#
# For example, to get the data for the stop outside St Paul's Cathedral in London,
# we pass the stop's ATCO code to `naptan.get_specific_stops`. In this case, the
# stop's code is `490012873B`.

# %% [markdown]
# <div class="admonition info">
# <p class="admonition-title">Info</p>
# <p>This function requires a list be passed into the <code>stops</code> parameter. Even just for a single stop.<br>Also, the code <em>must</em> passed in as a string.</p>
# </div>

# %%
import naptan

# note: passed in as a string inside a list
naptan.get_specific_stops(['490012873B'])
# Out:
#          ATCOCode NaptanCode PlateCode  CleardownCode           CommonName  \
# 14918  490012873B      49762       NaN            NaN  St Paul's Cathedral
#
#        CommonNameLang ShortCommonName  ShortCommonNameLang Landmark  \
# 14918             NaN             NaN                  NaN      ---
#
#        LandmarkLang  ... TimingStatus  DefaultWaitTime  Notes  NotesLang  \
# 14918           NaN  ...          OTH              NaN    NaN        NaN
#
#       AdministrativeAreaCode     CreationDateTime ModificationDateTime  \
# 14918                     82  2016-06-02T16:07:07  2022-01-06T14:54:07
#
#       RevisionNumber Modification  Status
# 14918              1       revise  active
#
# [1 rows x 43 columns]

# %% [markdown]
# ---
#
# We can pass in an arbitrary number of stops to the function. For example, below
# we pass in some more of the stops surrounding St Paul's.

# %%
import naptan

# note: passed in as a string inside a list
st_pauls_stops = ['490012873B', '490012873A', '490010199D', '490010199E']

naptan.get_specific_stops(st_pauls_stops)
# Out:
#          ATCOCode NaptanCode PlateCode  CleardownCode  \
# 11502  490010199D      53973       NaN            NaN
# 11503  490010199E      47995       NaN            NaN
# 14917  490012873A      53477       NaN            NaN
# 14918  490012873B      49762       NaN            NaN
#
#                       CommonName  CommonNameLang ShortCommonName  \
# 11502  New Change  Cannon Street             NaN             NaN
# 11503  New Change  Cannon Street             NaN             NaN
# 14917        St Paul's Cathedral             NaN             NaN
# 14918        St Paul's Cathedral             NaN             NaN
#
#        ShortCommonNameLang Landmark  LandmarkLang  ... TimingStatus  \
# 11502                  NaN      ---           NaN  ...          OTH
# 11503                  NaN      ---           NaN  ...          OTH
# 14917                  NaN      ---           NaN  ...          OTH
# 14918                  NaN      ---           NaN  ...          OTH
#
#        DefaultWaitTime  Notes  NotesLang AdministrativeAreaCode  \
# 11502              NaN    NaN        NaN                     82
# 11503              NaN    NaN        NaN                     82
# 14917              NaN    NaN        NaN                     82
# 14918              NaN    NaN        NaN                     82
#
#           CreationDateTime ModificationDateTime RevisionNumber Modification  \
# 11502  2016-03-07T14:50:08  2016-03-07T14:50:08              0       revise
# 11503  2016-03-07T14:50:08  2016-03-07T14:50:08              0       revise
# 14917  2016-06-02T16:07:07  2022-01-06T14:54:07              1       revise
# 14918  2016-06-02T16:07:07  2022-01-06T14:54:07              1       revise
#
#        Status
# 11502  active
# 11503  active
# 14917  active
# 14918  active
#
# [4 rows x 43 columns]
